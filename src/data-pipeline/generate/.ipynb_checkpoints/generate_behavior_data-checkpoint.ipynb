# %%
import random
from datetime import datetime, timedelta
import requests

class BehaviorDataGenerator:
    
    def __init__(self, api_base_url='http://localhost:8080/api'):
        self.api_base_url = api_base_url
        self.token = None
    
    def login(self, email, password):
        """Authentification avec diagnostic d'erreur"""
        print(f"🔑 Tentative de connexion pour : {email}...")
        
        response = requests.post(
            f"{self.api_base_url}/v1/auth/login",
            json={'email': email, 'motDePasse': password}
        )
        
        # Vérification du code statut
        if response.status_code == 200:
            try:
                data = response.json()
                self.token = data['token']
                print("✅ Authentifié avec succès.")
            except Exception as e:
                print(f"❌ Réponse reçue mais impossible de lire le JSON : {response.text}")
                raise e
        elif response.status_code == 404:
            print(f"❌ Erreur 404 : L'URL d'authentification est introuvable. Vérifiez 'v1/auth/login'")
        elif response.status_code == 401:
            print(f"❌ Erreur 401 : Email ou mot de passe incorrect pour {email}")
        else:
            print(f"❌ Erreur {response.status_code} : {response.text}")
            raise Exception("Échec de la connexion")
    
    def generate_user_behavior(self, user_id, num_interactions=50):
        """Génère des interactions réalistes pour un utilisateur"""
        headers = {'Authorization': f'Bearer {self.token}'}
        
        # Dans generate_user_behavior
        recipes_response = requests.get(
            f"{self.api_base_url}/v1/recettes/all",
            headers=headers
        )
        
        if recipes_response.status_code != 200:
            print(f"❌ Impossible de récupérer les recettes. Status: {recipes_response.status_code}")
            return
            
        recipes = recipes_response.json()
        
        if not recipes:
            print("❌ Aucune recette disponible")
            return
        
        print(f"🎭 Génération de {num_interactions} interactions pour user {user_id}")
        
        # Profil utilisateur 
        user_profile = self._create_user_profile()
        
        for i in range(num_interactions):
            # Choisir une recette selon les préférences
            recipe = self._choose_recipe(recipes, user_profile)
            
            # Type d'interaction
            interaction_type = random.choices(
                ['CONSULTATION', 'FAVORI_AJOUTE', 'PARTAGE', 'RECHERCHE'],
                weights=[60, 20, 10, 10]
            )[0]
            
            # Enregistrer l'interaction
            self._record_interaction(
                user_id, 
                recipe['id'], 
                interaction_type, 
                headers
            )
            
            # Parfois ajouter un commentaire
            if random.random() < 0.3:
                self._add_comment(user_id, recipe['id'], headers)
            
            # Parfois ajouter une note
            if random.random() < 0.4:
                self._add_rating(user_id, recipe['id'], headers)
            
            print(f"  [{i+1}/{num_interactions}] {interaction_type} - {recipe['titre'][:30]}")
        
        # Générer des recherches
        self._generate_searches(user_id, user_profile, headers, num=20)
        
        print(f"✅ Comportement généré pour user {user_id}")
    
    def _create_user_profile(self):
        """Crée un profil utilisateur cohérent"""
        cuisines = ['italienne', 'francaise', 'asiatique', 'mexicaine']
        types = ['entree', 'plat', 'dessert']
        
        return {
            'cuisine_preferee': random.choice(cuisines),
            'type_prefere': random.choice(types),
            'vegetarien': random.choice([True, False]),
            'niveau': random.choice(['FACILE', 'MOYEN', 'DIFFICILE']),
            'temps_max': random.choice([30, 60, 120])
        }
    
    def _choose_recipe(self, recipes, profile):
        """Choisit une recette selon le profil"""
        # Filtrer selon les préférences
        filtered = [
            r for r in recipes
            if (not profile['vegetarien'] or r.get('vegetarien', False))
        ]
        
        if not filtered:
            filtered = recipes
        
        # Favoriser les recettes correspondant aux préférences
        weights = [
            2 if r.get('cuisine') == profile['cuisine_preferee'] else 1
            for r in filtered
        ]
        
        return random.choices(filtered, weights=weights)[0]
    
    def _record_interaction(self, user_id, recipe_id, interaction_type, headers):
        """Enregistre une interaction"""
        try:
            requests.post(
                f"{self.api_base_url}/v1/recette-interactions/registrer",
                params={
                    'idUser': user_id,
                    'idRecette': recipe_id,
                    'typeInteraction': interaction_type,
                    'sessionId': f"session_{user_id}_{random.randint(1000, 9999)}"
                },
                headers=headers
            )
        except:
            pass
    
    def _add_comment(self, user_id, recipe_id, headers):
        """Ajoute un commentaire"""
        comments = [
            "Délicieux ! Je recommande",
            "Très bonne recette, facile à faire",
            "Mes enfants ont adoré",
            "Un peu long mais ça vaut le coup",
            "Super pour un repas en famille"
        ]
        
        try:
            requests.post(
                f"{self.api_base_url}/v1/recettes/{recipe_id}/commentaires/user/{user_id}",
                json={'contenu': random.choice(comments)},
                headers=headers
            )
        except:
            pass
    
    def _add_rating(self, user_id, recipe_id, headers):
        """Ajoute une note"""
        try:
            requests.post(
                f"{self.api_base_url}/v1/recettes/{recipe_id}/notes/user/{user_id}",
                json={'valeur': random.randint(3, 5)},
                headers=headers
            )
        except:
            pass
    
    def _generate_searches(self, user_id, profile, headers, num=20):
        """Génère des recherches cohérentes"""
        search_terms = [
            'pasta carbonara', 'tarte aux pommes', 'poulet rôti',
            'soupe de légumes', 'gâteau au chocolat', 'salade césar',
            'pizza margherita', 'curry de légumes', 'tiramisu'
        ]
        
        for _ in range(num):
            term = random.choice(search_terms)
            
            try:
                requests.post(
                    f"{self.api_base_url}/v1/historique-recherche",
                    params={'userId': user_id, 'terme': term},
                    json=[],
                    headers=headers
                )
            except:
                pass

# Utilisation
if __name__ == "__main__":
    generator = BehaviorDataGenerator()
    generator.login('dianekassi@admin.com', 'Mydayana48')
    
    # Générer pour plusieurs utilisateurs
    for user_id in range(1173, 1178):  # Users 1 à 10
        generator.generate_user_behavior(user_id, num_interactions=100)
# Out:
# 🔑 Tentative de connexion pour : dianekassi@admin.com...
# ✅ Authentifié avec succès.
# 🎭 Génération de 100 interactions pour user 1173
#   [1/100] FAVORI_AJOUTE - Boeuf braisé aux carottes
#   [2/100] CONSULTATION - Pintade farcie caramélisée aux
#   [3/100] CONSULTATION - Amour de saumon en papillote
#   [4/100] CONSULTATION - Filet mignon en croûte
#   [5/100] CONSULTATION - Amour de saumon en papillote
#   [6/100] CONSULTATION - Blanc de poulet aux endives, c
#   [7/100] CONSULTATION - Cuisse de canard à l'orientale
#   [8/100] RECHERCHE - Saumon à l'échalote
#   [9/100] CONSULTATION - Hachis Parmentier
#   [10/100] CONSULTATION - Mon couscous marocain
#   [11/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [12/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [13/100] CONSULTATION - Boeuf braisé aux carottes
#   [14/100] RECHERCHE - Mon couscous marocain
#   [15/100] FAVORI_AJOUTE - Boeuf Bourguignon rapide
#   [16/100] FAVORI_AJOUTE - Saucisses aux lentilles
#   [17/100] CONSULTATION - Filet mignon à l'italienne
#   [18/100] RECHERCHE - Tarte à la courgette et aux la
#   [19/100] CONSULTATION - La Vraie Moussaka Grecque
#   [20/100] CONSULTATION - Rougail saucisse
#   [21/100] CONSULTATION - Boeuf braisé aux carottes
#   [22/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [23/100] FAVORI_AJOUTE - Saumon à l'échalote
#   [24/100] CONSULTATION - Osso bucco de veau
#   [25/100] CONSULTATION - Filets de poulet à la moutarde
#   [26/100] CONSULTATION - Cassoulet à ma façon
#   [27/100] CONSULTATION - Boeuf bourguignon débutant
#   [28/100] CONSULTATION - Crêpe
#   [29/100] CONSULTATION - Ratatouille
#   [30/100] CONSULTATION - Boeuf Bourguignon rapide
#   [31/100] CONSULTATION - Osso bucco de veau
#   [32/100] CONSULTATION - Tarte à la courgette et aux la
#   [33/100] CONSULTATION - gratin de ravioles et courgett
#   [34/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [35/100] CONSULTATION - Tarte à la courgette et aux la
#   [36/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [37/100] CONSULTATION - Saumon à l'échalote
#   [38/100] CONSULTATION - Pintade farcie caramélisée aux
#   [39/100] CONSULTATION - Pintade farcie caramélisée aux
#   [40/100] CONSULTATION - Saucisses aux lentilles
#   [41/100] CONSULTATION - Curry de lotte au lait de coco
#   [42/100] CONSULTATION - Boeuf bourguignon débutant
#   [43/100] PARTAGE - Soupe Chinoise en plat princip
#   [44/100] PARTAGE - Osso bucco de veau
#   [45/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [46/100] CONSULTATION - Cuisses de poulet faciles et q
#   [47/100] CONSULTATION - Chili con carne facile
#   [48/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [49/100] CONSULTATION - Mon couscous marocain
#   [50/100] CONSULTATION - Magret de canard au miel et qu
#   [51/100] CONSULTATION - Filet mignon à l'italienne
#   [52/100] CONSULTATION - Cuisses de poulet faciles et q
#   [53/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [54/100] FAVORI_AJOUTE - Sauté de veau aux olives (Cors
#   [55/100] RECHERCHE - Pintade farcie caramélisée aux
#   [56/100] CONSULTATION - Curry de lotte au lait de coco
#   [57/100] FAVORI_AJOUTE - Boeuf braisé aux carottes
#   [58/100] FAVORI_AJOUTE - Filet mignon en croûte
#   [59/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [60/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [61/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [62/100] CONSULTATION - Gratin de cabillaud façon Paol
#   [63/100] FAVORI_AJOUTE - Chich taouk (poulet mariné gri
#   [64/100] CONSULTATION - Crêpe
#   [65/100] PARTAGE - Cake aux pommes
#   [66/100] CONSULTATION - Sauté de veau au chorizo
#   [67/100] CONSULTATION - Osso bucco de veau
#   [68/100] CONSULTATION - Blanquette de poisson
#   [69/100] CONSULTATION - Pâte à pizza fine
#   [70/100] RECHERCHE - Cuisse de canard à l'orientale
#   [71/100] CONSULTATION - Paupiettes de veau aux oignons
#   [72/100] PARTAGE - Saucisses aux lentilles
#   [73/100] PARTAGE - Lasagnes à la bolognaise
#   [74/100] FAVORI_AJOUTE - Ratatouille
#   [75/100] FAVORI_AJOUTE - Boeuf bourguignon débutant
#   [76/100] RECHERCHE - Filet mignon en croûte
#   [77/100] FAVORI_AJOUTE - Lentilles et saucisses de Mort
#   [78/100] CONSULTATION - Cake aux pommes
#   [79/100] CONSULTATION - Filets de poulet à la moutarde
#   [80/100] CONSULTATION - Amour de saumon en papillote
#   [81/100] CONSULTATION - Blanc de poulet aux endives, c
#   [82/100] FAVORI_AJOUTE - Osso bucco de veau
#   [83/100] FAVORI_AJOUTE - Carbonades flamandes tradition
#   [84/100] CONSULTATION - Tarte à la courgette et aux la
#   [85/100] FAVORI_AJOUTE - Filet de poulet au curry
#   [86/100] FAVORI_AJOUTE - Sauté de porc à la crème de mo
#   [87/100] FAVORI_AJOUTE - Lasagnes à la bolognaise
#   [88/100] CONSULTATION - Filet de poulet au curry
#   [89/100] RECHERCHE - Pintade farcie caramélisée aux
#   [90/100] CONSULTATION - Blanquette de poisson
#   [91/100] CONSULTATION - Brochettes de poulet express a
#   [92/100] FAVORI_AJOUTE - Brochettes de poulet express a
#   [93/100] CONSULTATION - gratin de ravioles et courgett
#   [94/100] CONSULTATION - Blanquette de poisson
#   [95/100] RECHERCHE - Boeuf braisé aux carottes
#   [96/100] PARTAGE - Cuisse de canard à l'orientale
#   [97/100] CONSULTATION - Magret de canard au miel et qu
#   [98/100] CONSULTATION - Tarte à la courgette et aux la
#   [99/100] CONSULTATION - Boeuf Bourguignon rapide
#   [100/100] CONSULTATION - Pâte à pizza fine
# ✅ Comportement généré pour user 1173
# 🎭 Génération de 100 interactions pour user 1174
#   [1/100] CONSULTATION - Boeuf braisé aux carottes
#   [2/100] RECHERCHE - Soupe Chinoise en plat princip
#   [3/100] RECHERCHE - Hachis Parmentier
#   [4/100] CONSULTATION - Paupiettes de veau aux oignons
#   [5/100] FAVORI_AJOUTE - Cuisse de canard à l'orientale
#   [6/100] PARTAGE - Sauté de veau au chorizo
#   [7/100] CONSULTATION - Paëlla fruits de mer, chorizo
#   [8/100] CONSULTATION - Blanquette de poisson
#   [9/100] FAVORI_AJOUTE - Tarte à la courgette et aux la
#   [10/100] CONSULTATION - Saucisses aux lentilles
#   [11/100] CONSULTATION - Rougail saucisse
#   [12/100] RECHERCHE - Chich taouk (poulet mariné gri
#   [13/100] CONSULTATION - Gratin de cabillaud façon Paol
#   [14/100] FAVORI_AJOUTE - Boeuf bourguignon débutant
#   [15/100] CONSULTATION - Cuisse de canard à l'orientale
#   [16/100] RECHERCHE - Tarte à la courgette et aux la
#   [17/100] CONSULTATION - Soupe Chinoise en plat princip
#   [18/100] CONSULTATION - Boeuf braisé aux carottes
#   [19/100] CONSULTATION - Filet de poulet au curry
#   [20/100] RECHERCHE - Tarte à la courgette et aux la
#   [21/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [22/100] CONSULTATION - Lentilles et saucisses de Mort
#   [23/100] CONSULTATION - Boeuf braisé aux carottes
#   [24/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [25/100] CONSULTATION - Lasagnes express
#   [26/100] CONSULTATION - Pâte à pizza fine
#   [27/100] CONSULTATION - Cuisse de poulet au curry au f
#   [28/100] CONSULTATION - Filet mignon rôti au cidre
#   [29/100] FAVORI_AJOUTE - Cake aux pommes
#   [30/100] PARTAGE - Lasagnes express
#   [31/100] FAVORI_AJOUTE - Chich taouk (poulet mariné gri
#   [32/100] RECHERCHE - Hachis Parmentier
#   [33/100] CONSULTATION - Boeuf braisé aux carottes
#   [34/100] PARTAGE - Saumon à l'échalote
#   [35/100] PARTAGE - Bourguignon délicieux
#   [36/100] CONSULTATION - Blanquette de poisson
#   [37/100] FAVORI_AJOUTE - Cassoulet à ma façon
#   [38/100] FAVORI_AJOUTE - Sauté de porc à la crème de mo
#   [39/100] PARTAGE - Boeuf Bourguignon rapide
#   [40/100] CONSULTATION - Soupe Chinoise en plat princip
#   [41/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [42/100] CONSULTATION - Filet mignon rôti au cidre
#   [43/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [44/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [45/100] CONSULTATION - Paupiettes de veau aux oignons
#   [46/100] CONSULTATION - Boeuf Bourguignon rapide
#   [47/100] PARTAGE - Osso bucco de veau
#   [48/100] FAVORI_AJOUTE - Filet mignon en croûte
#   [49/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [50/100] CONSULTATION - Gratin de courge butternut
#   [51/100] FAVORI_AJOUTE - Boeuf Bourguignon rapide
#   [52/100] CONSULTATION - Pasta Carbonara
#   [53/100] PARTAGE - Saucisses aux lentilles
#   [54/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [55/100] PARTAGE - Filet de poulet au curry
#   [56/100] CONSULTATION - Cassoulet à ma façon
#   [57/100] FAVORI_AJOUTE - Crêpe
#   [58/100] CONSULTATION - Sauté de porc à la crème de mo
#   [59/100] CONSULTATION - Paupiettes de veau aux oignons
#   [60/100] FAVORI_AJOUTE - Filet mignon rôti au cidre
#   [61/100] RECHERCHE - Lasagnes à la bolognaise
#   [62/100] CONSULTATION - Bourguignon délicieux
#   [63/100] FAVORI_AJOUTE - Cassoulet à ma façon
#   [64/100] FAVORI_AJOUTE - Sauce graine
#   [65/100] FAVORI_AJOUTE - Filet mignon en croûte
#   [66/100] CONSULTATION - Filet mignon à l'italienne
#   [67/100] FAVORI_AJOUTE - gratin de ravioles et courgett
#   [68/100] CONSULTATION - Filet mignon rôti au cidre
#   [69/100] CONSULTATION - Boeuf braisé aux carottes
#   [70/100] CONSULTATION - Hachis Parmentier
#   [71/100] FAVORI_AJOUTE - Lentilles et saucisses de Mort
#   [72/100] CONSULTATION - Poulet coco réunionnais
#   [73/100] CONSULTATION - Sauté de porc à la crème de mo
#   [74/100] PARTAGE - Porc au lait de coco (Tahiti)
#   [75/100] CONSULTATION - Paupiettes de veau aux oignons
#   [76/100] FAVORI_AJOUTE - Ratatouille
#   [77/100] RECHERCHE - Curry de lotte au lait de coco
#   [78/100] RECHERCHE - Pâte à pizza fine
#   [79/100] CONSULTATION - Cuisses de poulet faciles et q
#   [80/100] CONSULTATION - Chili con carne facile
#   [81/100] CONSULTATION - Pintade farcie caramélisée aux
#   [82/100] CONSULTATION - Chili con carne facile
#   [83/100] CONSULTATION - Amour de saumon en papillote
#   [84/100] PARTAGE - Blanquette de crevettes
#   [85/100] CONSULTATION - Mon couscous marocain
#   [86/100] CONSULTATION - Filets de poulet à la moutarde
#   [87/100] FAVORI_AJOUTE - Pâte à pizza fine
#   [88/100] RECHERCHE - Sauce graine
#   [89/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [90/100] CONSULTATION - Blanquette de lapin au rieslin
#   [91/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [92/100] CONSULTATION - Amour de saumon en papillote
#   [93/100] CONSULTATION - Blanquette de lapin au rieslin
#   [94/100] FAVORI_AJOUTE - Paupiettes de veau aux oignons
#   [95/100] CONSULTATION - Saumon à l'échalote
#   [96/100] PARTAGE - Blanquette de poisson
#   [97/100] FAVORI_AJOUTE - Chich taouk (poulet mariné gri
#   [98/100] FAVORI_AJOUTE - La Vraie Moussaka Grecque
#   [99/100] RECHERCHE - Chili con carne facile
#   [100/100] CONSULTATION - Filets de poulet à la moutarde
# ✅ Comportement généré pour user 1174
# 🎭 Génération de 100 interactions pour user 1175
#   [1/100] CONSULTATION - Tarte à la courgette et aux la
#   [2/100] CONSULTATION - Lasagnes à la bolognaise
#   [3/100] CONSULTATION - Blanc de poulet aux endives, c
#   [4/100] RECHERCHE - Porc au lait de coco (Tahiti)
#   [5/100] CONSULTATION - Cuisse de canard à l'orientale
#   [6/100] CONSULTATION - Mon couscous marocain
#   [7/100] CONSULTATION - Blanquette de crevettes
#   [8/100] RECHERCHE - Sauté de porc à la crème de mo
#   [9/100] CONSULTATION - Saumon à l'échalote
#   [10/100] CONSULTATION - Mon couscous marocain
#   [11/100] RECHERCHE - Boeuf braisé aux carottes
#   [12/100] CONSULTATION - Cuisse de poulet au curry au f
#   [13/100] PARTAGE - Magret de canard au miel et qu
#   [14/100] FAVORI_AJOUTE - Blanquette de poisson
#   [15/100] CONSULTATION - Hachis Parmentier
#   [16/100] FAVORI_AJOUTE - Paupiettes de veau aux oignons
#   [17/100] RECHERCHE - Lentilles et saucisses de Mort
#   [18/100] CONSULTATION - Cuisse de poulet au curry au f
#   [19/100] RECHERCHE - Lasagnes à la bolognaise
#   [20/100] FAVORI_AJOUTE - Osso bucco de veau
#   [21/100] PARTAGE - Soupe Chinoise en plat princip
#   [22/100] CONSULTATION - Tarte à la courgette et aux la
#   [23/100] FAVORI_AJOUTE - Sauté de veau au chorizo
#   [24/100] CONSULTATION - Brochettes de poulet express a
#   [25/100] RECHERCHE - Hachis Parmentier
#   [26/100] CONSULTATION - Brochettes de poulet express a
#   [27/100] CONSULTATION - Cake aux pommes
#   [28/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [29/100] FAVORI_AJOUTE - Sauté de veau aux olives (Cors
#   [30/100] CONSULTATION - La Vraie Moussaka Grecque
#   [31/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [32/100] RECHERCHE - Sauté de veau aux olives (Cors
#   [33/100] CONSULTATION - Paupiettes de veau aux oignons
#   [34/100] CONSULTATION - Sauté de veau au chorizo
#   [35/100] CONSULTATION - Amour de saumon en papillote
#   [36/100] CONSULTATION - Paëlla fruits de mer, chorizo
#   [37/100] CONSULTATION - Magret de canard au miel et qu
#   [38/100] CONSULTATION - Pintade farcie caramélisée aux
#   [39/100] CONSULTATION - gratin de ravioles et courgett
#   [40/100] FAVORI_AJOUTE - Chili con carne facile
#   [41/100] CONSULTATION - Chili con carne facile
#   [42/100] RECHERCHE - Mon couscous marocain
#   [43/100] CONSULTATION - Pâte à pizza fine
#   [44/100] CONSULTATION - Filet mignon rôti au cidre
#   [45/100] CONSULTATION - Saumon à l'échalote
#   [46/100] CONSULTATION - Blanquette de crevettes
#   [47/100] CONSULTATION - Blanc de poulet aux endives, c
#   [48/100] FAVORI_AJOUTE - Cake aux pommes
#   [49/100] CONSULTATION - Filet mignon rôti au cidre
#   [50/100] PARTAGE - Osso bucco de veau
#   [51/100] FAVORI_AJOUTE - Paupiettes de veau aux oignons
#   [52/100] FAVORI_AJOUTE - La Vraie Moussaka Grecque
#   [53/100] FAVORI_AJOUTE - Cassoulet à ma façon
#   [54/100] CONSULTATION - Blanquette de crevettes
#   [55/100] RECHERCHE - Cassoulet à ma façon
#   [56/100] CONSULTATION - Paupiettes de veau aux oignons
#   [57/100] CONSULTATION - Ratatouille
#   [58/100] FAVORI_AJOUTE - Tarte à la courgette et aux la
#   [59/100] RECHERCHE - Boeuf braisé aux carottes
#   [60/100] CONSULTATION - Blanquette de crevettes
#   [61/100] CONSULTATION - Blanquette de crevettes
#   [62/100] RECHERCHE - Osso bucco de veau
#   [63/100] CONSULTATION - Soupe Chinoise en plat princip
#   [64/100] FAVORI_AJOUTE - Soupe Chinoise en plat princip
#   [65/100] PARTAGE - gratin de ravioles et courgett
#   [66/100] CONSULTATION - Blanc de poulet aux endives, c
#   [67/100] CONSULTATION - Filet mignon rôti au cidre
#   [68/100] CONSULTATION - Blanc de poulet aux endives, c
#   [69/100] PARTAGE - Ratatouille
#   [70/100] CONSULTATION - Amour de saumon en papillote
#   [71/100] PARTAGE - Osso bucco de veau
#   [72/100] CONSULTATION - Pintade farcie caramélisée aux
#   [73/100] CONSULTATION - Blanquette de lapin au rieslin
#   [74/100] CONSULTATION - Amour de saumon en papillote
#   [75/100] CONSULTATION - Cuisse de canard à l'orientale
#   [76/100] PARTAGE - Blanc de poulet aux endives, c
#   [77/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [78/100] CONSULTATION - Chili con carne facile
#   [79/100] PARTAGE - Saucisses aux lentilles
#   [80/100] RECHERCHE - Cassoulet à ma façon
#   [81/100] FAVORI_AJOUTE - Hachis Parmentier
#   [82/100] PARTAGE - Crêpe
#   [83/100] CONSULTATION - Boeuf bourguignon débutant
#   [84/100] FAVORI_AJOUTE - Chili con carne facile
#   [85/100] RECHERCHE - Boeuf Bourguignon rapide
#   [86/100] FAVORI_AJOUTE - Amour de saumon en papillote
#   [87/100] RECHERCHE - Osso bucco de veau
#   [88/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [89/100] CONSULTATION - Sauté de veau au chorizo
#   [90/100] CONSULTATION - Chili con carne facile
#   [91/100] FAVORI_AJOUTE - Brochettes de poulet express a
#   [92/100] RECHERCHE - Sauté de veau au chorizo
#   [93/100] CONSULTATION - Brochettes de poulet express a
#   [94/100] PARTAGE - Filet mignon rôti au cidre
#   [95/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [96/100] FAVORI_AJOUTE - Sauté de veau aux olives (Cors
#   [97/100] CONSULTATION - Cuisses de poulet faciles et q
#   [98/100] CONSULTATION - Paupiettes de veau aux oignons
#   [99/100] RECHERCHE - Rougail saucisse
#   [100/100] FAVORI_AJOUTE - Sauce graine
# ✅ Comportement généré pour user 1175
# 🎭 Génération de 100 interactions pour user 1176
#   [1/100] CONSULTATION - Amour de saumon en papillote
#   [2/100] PARTAGE - Sauté de veau au chorizo
#   [3/100] FAVORI_AJOUTE - Pasta Carbonara
#   [4/100] CONSULTATION - Cuisse de poulet au curry au f
#   [5/100] CONSULTATION - Chili con carne facile
#   [6/100] CONSULTATION - Chili con carne facile
#   [7/100] RECHERCHE - Cuisse de canard à l'orientale
#   [8/100] CONSULTATION - Boeuf Bourguignon rapide
#   [9/100] CONSULTATION - Crêpe
#   [10/100] CONSULTATION - Poulet coco réunionnais
#   [11/100] CONSULTATION - Cuisse de canard à l'orientale
#   [12/100] FAVORI_AJOUTE - Paëlla fruits de mer, chorizo
#   [13/100] CONSULTATION - La Vraie Moussaka Grecque
#   [14/100] PARTAGE - Gratin de cabillaud façon Paol
#   [15/100] RECHERCHE - Sauce graine
#   [16/100] FAVORI_AJOUTE - Cuisses de poulet faciles et q
#   [17/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [18/100] CONSULTATION - Sauté de porc à la crème de mo
#   [19/100] CONSULTATION - Carbonades flamandes tradition
#   [20/100] CONSULTATION - Soupe Chinoise en plat princip
#   [21/100] CONSULTATION - Lasagnes à la bolognaise
#   [22/100] CONSULTATION - Cuisse de poulet au curry au f
#   [23/100] PARTAGE - Pâte à pizza fine
#   [24/100] PARTAGE - Sauté de veau aux olives (Cors
#   [25/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [26/100] FAVORI_AJOUTE - Crêpe
#   [27/100] FAVORI_AJOUTE - Tarte à la courgette et aux la
#   [28/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [29/100] CONSULTATION - Paupiettes de veau aux oignons
#   [30/100] RECHERCHE - gratin de ravioles et courgett
#   [31/100] FAVORI_AJOUTE - Crêpe
#   [32/100] CONSULTATION - Tarte à la courgette et aux la
#   [33/100] PARTAGE - Tarte à la courgette et aux la
#   [34/100] CONSULTATION - Bourguignon délicieux
#   [35/100] CONSULTATION - Mon couscous marocain
#   [36/100] CONSULTATION - Lasagnes express
#   [37/100] CONSULTATION - La Vraie Moussaka Grecque
#   [38/100] CONSULTATION - Pintade farcie caramélisée aux
#   [39/100] CONSULTATION - Magret de canard au miel et qu
#   [40/100] FAVORI_AJOUTE - Magret de canard au miel et qu
#   [41/100] CONSULTATION - Tarte à la courgette et aux la
#   [42/100] CONSULTATION - Cuisses de poulet faciles et q
#   [43/100] CONSULTATION - Pintade farcie caramélisée aux
#   [44/100] RECHERCHE - Crêpe
#   [45/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [46/100] CONSULTATION - Filets de poulet à la moutarde
#   [47/100] FAVORI_AJOUTE - Lasagnes express
#   [48/100] CONSULTATION - Mon couscous marocain
#   [49/100] CONSULTATION - Sauté de veau au chorizo
#   [50/100] FAVORI_AJOUTE - Bourguignon délicieux
#   [51/100] RECHERCHE - Chili con carne facile
#   [52/100] CONSULTATION - Tarte à la courgette et aux la
#   [53/100] CONSULTATION - Saumon à l'échalote
#   [54/100] PARTAGE - Filet de poulet au curry
#   [55/100] CONSULTATION - Rougail saucisse
#   [56/100] RECHERCHE - Tarte à la courgette et aux la
#   [57/100] FAVORI_AJOUTE - Boeuf bourguignon débutant
#   [58/100] CONSULTATION - Poulet coco réunionnais
#   [59/100] CONSULTATION - gratin de ravioles et courgett
#   [60/100] CONSULTATION - Boeuf Bourguignon rapide
#   [61/100] CONSULTATION - Cuisses de poulet faciles et q
#   [62/100] CONSULTATION - Brochettes de poulet express a
#   [63/100] CONSULTATION - Paupiettes de veau aux oignons
#   [64/100] CONSULTATION - Blanquette de poisson
#   [65/100] CONSULTATION - Lasagnes à la bolognaise
#   [66/100] RECHERCHE - Amour de saumon en papillote
#   [67/100] CONSULTATION - Tarte à la courgette et aux la
#   [68/100] CONSULTATION - Amour de saumon en papillote
#   [69/100] PARTAGE - Hachis Parmentier
#   [70/100] RECHERCHE - Blanquette de crevettes
#   [71/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [72/100] CONSULTATION - Cassoulet à ma façon
#   [73/100] CONSULTATION - Pintade farcie caramélisée aux
#   [74/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [75/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [76/100] FAVORI_AJOUTE - Magret de canard au miel et qu
#   [77/100] CONSULTATION - Boeuf braisé aux carottes
#   [78/100] CONSULTATION - Brochettes de poulet express a
#   [79/100] PARTAGE - Mon couscous marocain
#   [80/100] FAVORI_AJOUTE - Cuisse de poulet au curry au f
#   [81/100] FAVORI_AJOUTE - Poulet coco réunionnais
#   [82/100] FAVORI_AJOUTE - Mon couscous marocain
#   [83/100] CONSULTATION - Blanc de poulet aux endives, c
#   [84/100] FAVORI_AJOUTE - Crêpe
#   [85/100] FAVORI_AJOUTE - Pâte à pizza fine
#   [86/100] CONSULTATION - Tarte à la courgette et aux la
#   [87/100] CONSULTATION - Crêpe
#   [88/100] CONSULTATION - Sauté de porc à la crème de mo
#   [89/100] FAVORI_AJOUTE - Sauté de porc à la crème de mo
#   [90/100] CONSULTATION - Filet mignon en croûte
#   [91/100] FAVORI_AJOUTE - Chich taouk (poulet mariné gri
#   [92/100] CONSULTATION - Chili con carne facile
#   [93/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [94/100] FAVORI_AJOUTE - Gratin de cabillaud façon Paol
#   [95/100] RECHERCHE - Carbonades flamandes tradition
#   [96/100] FAVORI_AJOUTE - Lasagnes à la bolognaise
#   [97/100] RECHERCHE - Brochettes de poulet express a
#   [98/100] CONSULTATION - Chili con carne facile
#   [99/100] FAVORI_AJOUTE - Poulet coco réunionnais
#   [100/100] CONSULTATION - Sauté de veau au chorizo
# ✅ Comportement généré pour user 1176
# 🎭 Génération de 100 interactions pour user 1177
#   [1/100] FAVORI_AJOUTE - Cassoulet à ma façon
#   [2/100] CONSULTATION - Bourguignon délicieux
#   [3/100] CONSULTATION - Rougail saucisse
#   [4/100] RECHERCHE - Cuisse de canard à l'orientale
#   [5/100] PARTAGE - Boeuf Bourguignon rapide
#   [6/100] RECHERCHE - Rougail saucisse
#   [7/100] FAVORI_AJOUTE - Sauté de veau aux olives (Cors
#   [8/100] CONSULTATION - Gratin de cabillaud façon Paol
#   [9/100] FAVORI_AJOUTE - Blanquette de lapin au rieslin
#   [10/100] CONSULTATION - Magret de canard au miel et qu
#   [11/100] FAVORI_AJOUTE - Blanquette de crevettes
#   [12/100] FAVORI_AJOUTE - Chich taouk (poulet mariné gri
#   [13/100] CONSULTATION - Filet mignon rôti au cidre
#   [14/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [15/100] RECHERCHE - Saumon à l'échalote
#   [16/100] CONSULTATION - Poulet coco réunionnais
#   [17/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [18/100] CONSULTATION - Filet mignon à l'italienne
#   [19/100] CONSULTATION - Osso bucco de veau
#   [20/100] FAVORI_AJOUTE - Cuisse de canard à l'orientale
#   [21/100] CONSULTATION - Lasagnes express
#   [22/100] FAVORI_AJOUTE - Cassoulet à ma façon
#   [23/100] FAVORI_AJOUTE - Blanc de poulet aux endives, c
#   [24/100] CONSULTATION - Magret de canard au miel et qu
#   [25/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [26/100] PARTAGE - Curry de lotte au lait de coco
#   [27/100] CONSULTATION - Pasta Carbonara
#   [28/100] RECHERCHE - Ratatouille
#   [29/100] CONSULTATION - Carbonades flamandes tradition
#   [30/100] CONSULTATION - Paupiettes de veau aux oignons
#   [31/100] FAVORI_AJOUTE - Sauce graine
#   [32/100] FAVORI_AJOUTE - Blanquette de lapin au rieslin
#   [33/100] CONSULTATION - Lasagnes express
#   [34/100] FAVORI_AJOUTE - Sauté de veau aux olives (Cors
#   [35/100] FAVORI_AJOUTE - Filet mignon à l'italienne
#   [36/100] CONSULTATION - Saumon à l'échalote
#   [37/100] CONSULTATION - Pasta Carbonara
#   [38/100] CONSULTATION - Cuisses de poulet faciles et q
#   [39/100] CONSULTATION - Chili con carne facile
#   [40/100] PARTAGE - La Vraie Moussaka Grecque
#   [41/100] PARTAGE - Chich taouk (poulet mariné gri
#   [42/100] CONSULTATION - Boeuf bourguignon débutant
#   [43/100] FAVORI_AJOUTE - Mon couscous marocain
#   [44/100] FAVORI_AJOUTE - Brochettes de poulet express a
#   [45/100] CONSULTATION - Sauté de veau au chorizo
#   [46/100] RECHERCHE - Boeuf Bourguignon rapide
#   [47/100] CONSULTATION - Blanc de poulet aux endives, c
#   [48/100] CONSULTATION - Tarte à la courgette et aux la
#   [49/100] CONSULTATION - Curry de lotte au lait de coco
#   [50/100] CONSULTATION - Blanc de poulet aux endives, c
#   [51/100] CONSULTATION - Sauté de veau aux olives (Cors
#   [52/100] CONSULTATION - Pasta Carbonara
#   [53/100] CONSULTATION - Blanquette de poisson
#   [54/100] CONSULTATION - Crêpe
#   [55/100] PARTAGE - Rougail saucisse
#   [56/100] CONSULTATION - Amour de saumon en papillote
#   [57/100] CONSULTATION - Pâte à pizza fine
#   [58/100] FAVORI_AJOUTE - Gratin de cabillaud façon Paol
#   [59/100] CONSULTATION - Filet de poulet au curry
#   [60/100] CONSULTATION - Sauté de porc à la crème de mo
#   [61/100] RECHERCHE - Porc au lait de coco (Tahiti)
#   [62/100] FAVORI_AJOUTE - Cuisses de poulet faciles et q
#   [63/100] CONSULTATION - Filet mignon en croûte
#   [64/100] PARTAGE - Cuisse de poulet au curry au f
#   [65/100] CONSULTATION - Tarte à la courgette et aux la
#   [66/100] CONSULTATION - Lentilles et saucisses de Mort
#   [67/100] CONSULTATION - Paupiettes de veau aux oignons
#   [68/100] CONSULTATION - Ratatouille
#   [69/100] CONSULTATION - Cuisse de poulet au curry au f
#   [70/100] CONSULTATION - Boeuf braisé aux carottes
#   [71/100] FAVORI_AJOUTE - Gratin de cabillaud façon Paol
#   [72/100] CONSULTATION - Blanquette de lapin au rieslin
#   [73/100] CONSULTATION - Porc au lait de coco (Tahiti)
#   [74/100] CONSULTATION - Blanquette de crevettes
#   [75/100] CONSULTATION - Cassoulet à ma façon
#   [76/100] CONSULTATION - Lasagnes express
#   [77/100] RECHERCHE - Chili con carne facile
#   [78/100] CONSULTATION - Crêpe
#   [79/100] CONSULTATION - Tarte à la courgette et aux la
#   [80/100] CONSULTATION - Pintade farcie caramélisée aux
#   [81/100] CONSULTATION - Cuisses de poulet faciles et q
#   [82/100] RECHERCHE - Amour de saumon en papillote
#   [83/100] CONSULTATION - Sauté de porc à la crème de mo
#   [84/100] CONSULTATION - Filets de poulet à la moutarde
#   [85/100] RECHERCHE - Filet de poulet au curry
#   [86/100] CONSULTATION - gratin de ravioles et courgett
#   [87/100] CONSULTATION - Sauté de porc à la crème de mo
#   [88/100] CONSULTATION - Gratin de courge butternut
#   [89/100] CONSULTATION - Filets de poulet à la moutarde
#   [90/100] CONSULTATION - Gratin de cabillaud façon Paol
#   [91/100] RECHERCHE - Blanquette de lapin au rieslin
#   [92/100] CONSULTATION - Chich taouk (poulet mariné gri
#   [93/100] FAVORI_AJOUTE - Soupe Chinoise en plat princip
#   [94/100] FAVORI_AJOUTE - Soupe Chinoise en plat princip
#   [95/100] FAVORI_AJOUTE - Porc au lait de coco (Tahiti)
#   [96/100] PARTAGE - Cuisse de canard à l'orientale
#   [97/100] CONSULTATION - Lasagnes express
#   [98/100] FAVORI_AJOUTE - Soupe Chinoise en plat princip
#   [99/100] PARTAGE - Soupe Chinoise en plat princip
#   [100/100] PARTAGE - Lasagnes express
# ✅ Comportement généré pour user 1177
