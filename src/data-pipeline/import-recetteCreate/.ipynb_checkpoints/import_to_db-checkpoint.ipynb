# %%
import pandas as pd
import json
import requests
import time  

class RecipeImporter:
    def __init__(self, api_base_url='http://localhost:8080/api'):
        self.api_base_url = api_base_url
        self.token = None
        self.user_id = None

    def login(self, email, password):
        """Authentification"""
        response = requests.post(
            f"{self.api_base_url}/v1/auth/login",
            json={'email': email, 'motDePasse': password}
        )
        
        if response.status_code == 200:
            data = response.json()
            self.token = data.get('token')
            
            # --- DEBUG : Affiche tout pour vérifier où est l'ID ---
            # print("Réponse API Login:", data) 
            
            # On cherche l'ID (adaptez 'id' selon votre JSON de réponse)
            self.user_id = data.get('id') or data.get('userId')
            
            if self.user_id is None:
                print("⚠️ Attention: Token reçu mais ID utilisateur introuvable dans la réponse.")
            else:
                print(f"✅ Authentifié (User ID: {self.user_id})")
        else:
            raise Exception(f"❌ Échec authentification: {response.text}")

    def import_recipe(self, recipe_data, user_id):
        """Importe une recette via l'API"""
        if user_id is None:
            print("❌ Annulation: user_id est None. Impossible de créer la recette.")
            return None
            
        headers = {'Authorization': f'Bearer {self.token}'}
        
        # Nettoyage des données pour éviter les erreurs de type
        recette_payload = {
            'titre': str(recipe_data.get('titre', 'Sans titre')),
            'description': str(recipe_data.get('description', '')),
            'tempsPreparation': int(float(recipe_data.get('temps_preparation', 0))),
            'tempsCuisson': int(float(recipe_data.get('temps_cuisson', 0))),
            'difficulte': str(recipe_data.get('difficulte', 'MOYEN'))
        }
        
        response = requests.post(
            f"{self.api_base_url}/v1/recettes/user/{user_id}",
            json=recette_payload,
            headers=headers
        )
        
        if response.status_code == 201:
            recette_id = response.json().get('id')
            print(f"✓ Recette créée: {recette_payload['titre']} (ID: {recette_id})")
            return recette_id
        else:
            print(f"❌ Erreur création ({recette_payload['titre']}): {response.text}")
            return None

    def import_all(self, csv_file, max_recipes=None):
        df = pd.read_csv(csv_file).fillna("")
        if max_recipes:
            df = df.head(max_recipes)
            
        print(f"\n📥 Import de {len(df)} recettes...")
        
        for idx, row in df.iterrows():
            print(f"[{idx+1}/{len(df)}]", end=" ")
            self.import_recipe(row.to_dict(), user_id=self.user_id)
            time.sleep(0.2) # Plus de NameError ici
        
        print(f"\n✅ Import terminé!")

# Utilisation
if __name__ == "__main__":
    # Utilisation
    importer = RecipeImporter()
    importer.login('diane@gmail.com', 'Mydayana48')
    
    # SI l'ID reste None, forcez-le avec l'ID que vous avez en base de données
    if importer.user_id is None:
        importer.user_id = 1179  # Remplacez 1 par l'ID réel de diane@gmail.com en BDD
    
    importer.import_all('recettes_clean.csv', max_recipes=50)
# Out:
# ✅ Authentifié (User ID: 1178)
#
# 📥 Import de 50 recettes...
# [1/50] ✓ Recette créée: Paupiettes de veau aux oignons et tomates (ID: 57)
# [2/50] ✓ Recette créée: Porc au lait de coco (Tahiti) (ID: 58)
